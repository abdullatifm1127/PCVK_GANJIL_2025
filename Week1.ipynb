# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullatifm1127/PCVK_GANJIL_2025/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')

  tinggi = image_2.shape[0]
  lebar = image_2.shape[1]
  print("resolusi image: tinggi x lebar = ", tinggi, "x", lebar)
  cv2_imshow(image_2)

  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

  for y in range (lebar):
    image_3[int((tinggi)/2), y] = [255,255,255]

  final_frame = cv.hconcat((image_2, image_3))
  cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# resolusi image: tinggi x lebar =  276 x 400
# <PIL.Image.Image image mode=RGB size=400x276>
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# resolusi image: tinggi x lebar =  286 x 400
# <PIL.Image.Image image mode=RGB size=400x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 1. Karena praktis, fleksibel, powerful, dan meminimalisir intalasi lokal

# %% [markdown]
# 2. **PyPREP**
#
# - Digunakan untuk preprocessing sinyal EEG misalnya menghilangkan noise/artifact dari data EEG.
#
# - Berguna di penelitian neuro-informatika atau analisis sinyal biomedis.
#
#   **SciPy**
#
# - Library ilmiah & komputasi numerik.
#
# - Banyak digunakan untuk operasi matematis.
#
# - Untuk pengolahan sinyal atau analisis data numerik.
#
#   **Weights & Biases (wandb)**
#
# - Tool untuk eksperimen machine learning.
#
# - Membantu melacak parameter, hasil    training, grafik loss/akurasi, dan membandingkan model.
#
# - Berguna saat menjalankan eksperimen berulang agar hasilnya terdokumentasi dengan baik.
#
#   **pyECG**
#
# - Library khusus untuk pemrosesan sinyal ECG.
#
# - Biasanya dipakai untuk mendeteksi detak jantung, atau analisis kesehatan jantung.
#
# Tidak selalu karena library yang dipakai disesuaikan dengan jenis data dan tujuan praktikum.

# %% [markdown]
# 3. Fungsi cv.resize() digunakan untuk mengubah ukuran gambar. Parameter(0,0) berarti ukuran target tidak ditentukan secara langsung. fx=0.5 dan fy=0.5 faktor skala lebar x dan tinggi y dikalikan 0.5. Artinya gambar diperkecil menjadi setengah dari ukuran aslinya baik lebar maupun tingginya.
#
# Jika tidak dilakukan maka:
# - Ukuran gambar tetap besar. Bisa membuat proses pengolahan citra jadi lebih lambat karena lebih banyak piksel yang diproses.
# - Lebih boros memori. gambar besar membutuhkan RAM/VRAM lebih besar.
# - Visualisasi kadang gambar terlalu besar untuk ditampilkan di layar notebook/Colab , sehingga sulit diamati

# %% [markdown]
# 4. [255,255,255] adalah warna piksel:
# - 255 untuk B (biru)
# - 255 untuk G (hijau)
# - 255 untuk R (merah)
# Jika  ketiganya bernilai 255 maka warnanya menjadi putih
#
# Jadi [255,255,255] digunakan untuk memberi warna putih pada setiap piksel di baris tengah gambar sehingga hasilnya adalah garis putih horizontal melintang di tengah gambar.

# %% [markdown]
# 5.
#
# **Jumlah pixel menentukan resolusi**
#
#
# *   Resolusi tinggi = lebih banyak piksel gambar lebih tajam.
# *   Resolusi rendah = lebih sedikit piksel gambar kurang detail.
#
# **Kualitas visual**
#
#
# *   Pada resolusi tinggi objek halus lebih terlihat jelas.
# *   Pada resolusi rendah, detail bisa hilang atau jadi kotak-kotak

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

tinggi, lebar = image_3.shape[:2]

cv.line(image_3, (lebar//2, 0), (lebar//2, tinggi), (255,255,255), 2)
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

tinggi, lebar = image_3.shape[:2]

cv.line(image_3, (lebar-1,0), (0,tinggi-1), (255,255,255), 2)
cv.line(image_3, (0,0), (lebar-1, tinggi-1), (255,255,255), 2)
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

tinggi, lebar = image_3.shape[:2]

y_tengah = tinggi // 2
panjang_garis = 200

x_awal = (lebar - panjang_garis) // 2
x_akhir = (lebar + panjang_garis) // 2

cv.line(image_3, (x_awal, y_tengah), (x_akhir, y_tengah), (255,255,255), 2)
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

tinggi, lebar = image_3.shape[:2]
kotak_tinggi = 100
kotak_lebar = 150

x_awal = (lebar - kotak_lebar) // 2
y_awal = (tinggi - kotak_tinggi) // 2

for y in range(y_awal, y_awal + kotak_tinggi):
    for x in range(x_awal, x_awal + kotak_lebar):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
